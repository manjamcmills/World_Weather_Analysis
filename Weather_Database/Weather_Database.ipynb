# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Import the requests library.
import requests

# Import the API key.
import os
from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv("Open_Weather_API_key")

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
len(url)
# Out:
# 100

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data2 = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data2 list.
        city_data2.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | souillac
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | namibe
# Processing Record 4 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | san matias
# Processing Record 7 of Set 1 | moorhead
# Processing Record 8 of Set 1 | uige
# Processing Record 9 of Set 1 | pericos
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | cidreira
# Processing Record 13 of Set 1 | bara
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | tazovskiy
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | dalby
# Processing Record 25 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | dwarka
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 1 | anloga
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | anadyr
# Processing Record 34 of Set 1 | anjozorobe
# Processing Record 35 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 1 | ponta do sol
# Processing Record 37 of Set 1 | kristiansund
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | alta floresta
# Processing Record 41 of Set 1 | rawson
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | vardo
# Processing Record 45 of Set 1 | coihaique
# Processing Record 46 of Set 1 | flinders
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | synya
# Processing Record 49 of Set 1 | mount gambier
# Processing Record 50 of Set 1 | sabi
# Processing Record 1 of Set 2 | boyolangu
# Processing Record 2 of Set 2 | beringovskiy
# Processing Record 3 of Set 2 | deputatskiy
# Processing Record 4 of Set 2 | itarema
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | waipawa
# Processing Record 7 of Set 2 | collie
# Processing Record 8 of Set 2 | estacion coahuila
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | berdigestyakh
# Processing Record 11 of Set 2 | huarmey
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | bambous virieux
# Processing Record 14 of Set 2 | newport
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | leningradskiy
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | belyy yar
# Processing Record 19 of Set 2 | tabou
# Processing Record 20 of Set 2 | vao
# Processing Record 21 of Set 2 | bud
# Processing Record 22 of Set 2 | yarmouth
# Processing Record 23 of Set 2 | henties bay
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | lokachi
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | balykshi
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | atambua
# Processing Record 30 of Set 2 | srednekolymsk
# Processing Record 31 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 32 of Set 2 | puerto palomas
# Processing Record 33 of Set 2 | katsuura
# Processing Record 34 of Set 2 | sitka
# Processing Record 35 of Set 2 | tuatapere
# Processing Record 36 of Set 2 | singapore
# Processing Record 37 of Set 2 | khakhea
# Processing Record 38 of Set 2 | yar-sale
# Processing Record 39 of Set 2 | kirakira
# Processing Record 40 of Set 2 | panguma
# Processing Record 41 of Set 2 | inirida
# Processing Record 42 of Set 2 | casper
# Processing Record 43 of Set 2 | luderitz
# Processing Record 44 of Set 2 | jeremie
# Processing Record 45 of Set 2 | eureka
# Processing Record 46 of Set 2 | labuhan
# Processing Record 47 of Set 2 | falmouth
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | poum
# Processing Record 50 of Set 2 | barra
# Processing Record 1 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | kavieng
# Processing Record 4 of Set 3 | lengshuitan
# Processing Record 5 of Set 3 | botwood
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | sanbu
# Processing Record 8 of Set 3 | khatanga
# Processing Record 9 of Set 3 | chokurdakh
# Processing Record 10 of Set 3 | aktau
# Processing Record 11 of Set 3 | aykhal
# Processing Record 12 of Set 3 | orlik
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | cestas
# Processing Record 15 of Set 3 | cape town
# Processing Record 16 of Set 3 | walvis bay
# Processing Record 17 of Set 3 | charters towers
# Processing Record 18 of Set 3 | pirovskoye
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | amazar
# Processing Record 22 of Set 3 | codrington
# Processing Record 23 of Set 3 | ostrovnoy
# Processing Record 24 of Set 3 | pacific grove
# Processing Record 25 of Set 3 | lata
# Processing Record 26 of Set 3 | zaoyang
# Processing Record 27 of Set 3 | hofn
# Processing Record 28 of Set 3 | cabo san lucas
# Processing Record 29 of Set 3 | challans
# Processing Record 30 of Set 3 | iqaluit
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | margate
# Processing Record 33 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 3 | gunzenhausen
# Processing Record 35 of Set 3 | san luis
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | mayo
# Processing Record 38 of Set 3 | puerto escondido
# Processing Record 39 of Set 3 | imbituba
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | namatanai
# Processing Record 42 of Set 3 | laguna
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | pitogo
# Processing Record 45 of Set 3 | santa rosa
# Processing Record 46 of Set 3 | gelemso
# Processing Record 47 of Set 3 | lufilufi
# Processing Record 48 of Set 3 | touros
# Processing Record 49 of Set 3 | beidao
# Processing Record 50 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | boysun
# Processing Record 3 of Set 4 | zhezkazgan
# Processing Record 4 of Set 4 | chapais
# Processing Record 5 of Set 4 | severodvinsk
# Processing Record 6 of Set 4 | vagur
# Processing Record 7 of Set 4 | bilibino
# Processing Record 8 of Set 4 | bontang
# Processing Record 9 of Set 4 | giyani
# Processing Record 10 of Set 4 | suao
# City not found. Skipping...
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | sao filipe
# Processing Record 13 of Set 4 | rodrigues alves
# Processing Record 14 of Set 4 | coralville
# Processing Record 15 of Set 4 | ozinki
# Processing Record 16 of Set 4 | hue
# Processing Record 17 of Set 4 | talca
# Processing Record 18 of Set 4 | eirunepe
# Processing Record 19 of Set 4 | severo-kurilsk
# Processing Record 20 of Set 4 | butaritari
# Processing Record 21 of Set 4 | qaqortoq
# Processing Record 22 of Set 4 | betioky
# Processing Record 23 of Set 4 | hasaki
# Processing Record 24 of Set 4 | barrow
# Processing Record 25 of Set 4 | saint-philippe
# Processing Record 26 of Set 4 | avigliana
# Processing Record 27 of Set 4 | yining
# Processing Record 28 of Set 4 | zafra
# Processing Record 29 of Set 4 | mar del plata
# Processing Record 30 of Set 4 | provideniya
# Processing Record 31 of Set 4 | los llanos de aridane
# Processing Record 32 of Set 4 | tarpon springs
# Processing Record 33 of Set 4 | shengjin
# Processing Record 34 of Set 4 | dunedin
# Processing Record 35 of Set 4 | torbay
# Processing Record 36 of Set 4 | mahoba
# Processing Record 37 of Set 4 | miri
# Processing Record 38 of Set 4 | san cristobal
# Processing Record 39 of Set 4 | innisfail
# Processing Record 40 of Set 4 | dasoguz
# Processing Record 41 of Set 4 | taveta
# Processing Record 42 of Set 4 | dalvik
# Processing Record 43 of Set 4 | kutum
# Processing Record 44 of Set 4 | nanortalik
# Processing Record 45 of Set 4 | saint-augustin
# Processing Record 46 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 4 | chuy
# Processing Record 49 of Set 4 | dumka
# Processing Record 50 of Set 4 | chadiza
# Processing Record 1 of Set 5 | praya
# Processing Record 2 of Set 5 | hackettstown
# Processing Record 3 of Set 5 | esperance
# Processing Record 4 of Set 5 | carnarvon
# Processing Record 5 of Set 5 | san patricio
# Processing Record 6 of Set 5 | ilulissat
# Processing Record 7 of Set 5 | axim
# Processing Record 8 of Set 5 | tarare
# Processing Record 9 of Set 5 | mugla
# Processing Record 10 of Set 5 | upernavik
# Processing Record 11 of Set 5 | ribeira brava
# Processing Record 12 of Set 5 | abay
# Processing Record 13 of Set 5 | lebu
# Processing Record 14 of Set 5 | shar
# Processing Record 15 of Set 5 | komsomolskiy
# Processing Record 16 of Set 5 | victoria
# Processing Record 17 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 18 of Set 5 | east london
# Processing Record 19 of Set 5 | bom jesus
# Processing Record 20 of Set 5 | salina
# Processing Record 21 of Set 5 | celestun
# Processing Record 22 of Set 5 | khanpur
# Processing Record 23 of Set 5 | saskylakh
# Processing Record 24 of Set 5 | bredasdorp
# Processing Record 25 of Set 5 | sumbawanga
# Processing Record 26 of Set 5 | ouesso
# Processing Record 27 of Set 5 | yulara
# Processing Record 28 of Set 5 | impfondo
# Processing Record 29 of Set 5 | havre-saint-pierre
# Processing Record 30 of Set 5 | xiamen
# Processing Record 31 of Set 5 | aripuana
# Processing Record 32 of Set 5 | nalut
# Processing Record 33 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 5 | yerofey pavlovich
# Processing Record 35 of Set 5 | kaitangata
# Processing Record 36 of Set 5 | acapulco
# Processing Record 37 of Set 5 | fort nelson
# Processing Record 38 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 5 | mongo
# Processing Record 40 of Set 5 | thompson
# Processing Record 41 of Set 5 | bam
# Processing Record 42 of Set 5 | san quintin
# Processing Record 43 of Set 5 | gorontalo
# Processing Record 44 of Set 5 | houma
# Processing Record 45 of Set 5 | narsaq
# Processing Record 46 of Set 5 | ambovombe
# Processing Record 47 of Set 5 | tual
# Processing Record 48 of Set 5 | sorong
# Processing Record 49 of Set 5 | bulawayo
# Processing Record 50 of Set 5 | yumen
# Processing Record 1 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 6 | lagoa
# Processing Record 3 of Set 6 | lasa
# Processing Record 4 of Set 6 | ianca
# Processing Record 5 of Set 6 | kontagora
# Processing Record 6 of Set 6 | dire dawa
# Processing Record 7 of Set 6 | tiznit
# Processing Record 8 of Set 6 | rio pardo de minas
# Processing Record 9 of Set 6 | ugoofaaru
# Processing Record 10 of Set 6 | karangampel
# Processing Record 11 of Set 6 | te anau
# Processing Record 12 of Set 6 | faya
# Processing Record 13 of Set 6 | aden
# Processing Record 14 of Set 6 | taoudenni
# Processing Record 15 of Set 6 | caxito
# Processing Record 16 of Set 6 | saint-francois
# Processing Record 17 of Set 6 | juxian
# City not found. Skipping...
# Processing Record 18 of Set 6 | boli
# Processing Record 19 of Set 6 | zaozerne
# Processing Record 20 of Set 6 | sisimiut
# Processing Record 21 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 23 of Set 6 | ushtobe
# Processing Record 24 of Set 6 | elko
# Processing Record 25 of Set 6 | raga
# Processing Record 26 of Set 6 | esso
# Processing Record 27 of Set 6 | praia da vitoria
# Processing Record 28 of Set 6 | candolim
# Processing Record 29 of Set 6 | pevek
# Processing Record 30 of Set 6 | belmonte
# Processing Record 31 of Set 6 | teacapan
# Processing Record 32 of Set 6 | tarko-sale
# Processing Record 33 of Set 6 | cairns
# Processing Record 34 of Set 6 | pimentel
# Processing Record 35 of Set 6 | gumrak
# Processing Record 36 of Set 6 | novosokolniki
# Processing Record 37 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 38 of Set 6 | bumba
# Processing Record 39 of Set 6 | bela
# Processing Record 40 of Set 6 | lewiston
# Processing Record 41 of Set 6 | dingle
# Processing Record 42 of Set 6 | morehead
# Processing Record 43 of Set 6 | temyasovo
# Processing Record 44 of Set 6 | saint george
# Processing Record 45 of Set 6 | pandan
# Processing Record 46 of Set 6 | ambilobe
# Processing Record 47 of Set 6 | andenes
# Processing Record 48 of Set 6 | sao joao da barra
# Processing Record 49 of Set 6 | dubbo
# Processing Record 50 of Set 6 | mitchell
# Processing Record 1 of Set 7 | great falls
# Processing Record 2 of Set 7 | waingapu
# Processing Record 3 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 7 | tupelo
# Processing Record 5 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 6 of Set 7 | tautira
# Processing Record 7 of Set 7 | chimoio
# Processing Record 8 of Set 7 | juneau
# Processing Record 9 of Set 7 | saviese
# Processing Record 10 of Set 7 | yenagoa
# Processing Record 11 of Set 7 | husavik
# Processing Record 12 of Set 7 | altamira
# Processing Record 13 of Set 7 | talpa
# Processing Record 14 of Set 7 | golden
# Processing Record 15 of Set 7 | cherskiy
# Processing Record 16 of Set 7 | klaksvik
# Processing Record 17 of Set 7 | florianopolis
# Processing Record 18 of Set 7 | yashkino
# Processing Record 19 of Set 7 | dharchula
# Processing Record 20 of Set 7 | longyearbyen
# Processing Record 21 of Set 7 | faanui
# Processing Record 22 of Set 7 | jinchang
# Processing Record 23 of Set 7 | noumea
# Processing Record 24 of Set 7 | jining
# Processing Record 25 of Set 7 | port stanley
# Processing Record 26 of Set 7 | carutapera
# Processing Record 27 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 7 | changping
# Processing Record 29 of Set 7 | lompoc
# Processing Record 30 of Set 7 | tirano
# Processing Record 31 of Set 7 | matoury
# Processing Record 32 of Set 7 | qui nhon
# Processing Record 33 of Set 7 | palmer
# Processing Record 34 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 7 | bang saphan
# Processing Record 36 of Set 7 | savannah bight
# Processing Record 37 of Set 7 | zhob
# Processing Record 38 of Set 7 | alihe
# Processing Record 39 of Set 7 | tabas
# Processing Record 40 of Set 7 | huntsville
# Processing Record 41 of Set 7 | almiros
# City not found. Skipping...
# Processing Record 42 of Set 7 | sherlovaya gora
# Processing Record 43 of Set 7 | camana
# Processing Record 44 of Set 7 | bechem
# Processing Record 45 of Set 7 | wasilla
# Processing Record 46 of Set 7 | zaozhuang
# Processing Record 47 of Set 7 | abnub
# Processing Record 48 of Set 7 | pangoa
# Processing Record 49 of Set 7 | kieta
# Processing Record 50 of Set 7 | jorhat
# Processing Record 1 of Set 8 | arinos
# Processing Record 2 of Set 8 | lima
# Processing Record 3 of Set 8 | micheweni
# Processing Record 4 of Set 8 | tiksi
# Processing Record 5 of Set 8 | nampula
# Processing Record 6 of Set 8 | camacha
# Processing Record 7 of Set 8 | quatre cocos
# Processing Record 8 of Set 8 | kaluga
# Processing Record 9 of Set 8 | seoul
# Processing Record 10 of Set 8 | ewa beach
# Processing Record 11 of Set 8 | zolotukhino
# Processing Record 12 of Set 8 | mosquera
# Processing Record 13 of Set 8 | naze
# Processing Record 14 of Set 8 | locri
# Processing Record 15 of Set 8 | ketchikan
# Processing Record 16 of Set 8 | menongue
# Processing Record 17 of Set 8 | clyde river
# Processing Record 18 of Set 8 | washington
# Processing Record 19 of Set 8 | marzuq
# Processing Record 20 of Set 8 | maniitsoq
# Processing Record 21 of Set 8 | la primavera
# Processing Record 22 of Set 8 | mapiripan
# Processing Record 23 of Set 8 | talnakh
# Processing Record 24 of Set 8 | chabahar
# Processing Record 25 of Set 8 | ludvika
# Processing Record 26 of Set 8 | fare
# Processing Record 27 of Set 8 | chakia
# Processing Record 28 of Set 8 | atikokan
# Processing Record 29 of Set 8 | usinsk
# Processing Record 30 of Set 8 | bay roberts
# Processing Record 31 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 8 | casablanca
# Processing Record 33 of Set 8 | ngunguru
# Processing Record 34 of Set 8 | puerto el triunfo
# Processing Record 35 of Set 8 | urubicha
# Processing Record 36 of Set 8 | acari
# Processing Record 37 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 8 | ndola
# Processing Record 39 of Set 8 | korla
# Processing Record 40 of Set 8 | sarh
# Processing Record 41 of Set 8 | fatezh
# Processing Record 42 of Set 8 | grand gaube
# Processing Record 43 of Set 8 | manoel urbano
# Processing Record 44 of Set 8 | mandalgovi
# Processing Record 45 of Set 8 | sonoita
# Processing Record 46 of Set 8 | los aquijes
# Processing Record 47 of Set 8 | tubuala
# Processing Record 48 of Set 8 | jalu
# Processing Record 49 of Set 8 | surt
# Processing Record 50 of Set 8 | nchelenge
# Processing Record 1 of Set 9 | amapa
# Processing Record 2 of Set 9 | les cayes
# Processing Record 3 of Set 9 | bom jesus do galho
# Processing Record 4 of Set 9 | umtata
# Processing Record 5 of Set 9 | shihezi
# Processing Record 6 of Set 9 | disna
# Processing Record 7 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 8 of Set 9 | dicabisagan
# Processing Record 9 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 9 | kavaratti
# Processing Record 11 of Set 9 | kindu
# Processing Record 12 of Set 9 | saint-michel-des-saints
# Processing Record 13 of Set 9 | iraucuba
# Processing Record 14 of Set 9 | rybinsk
# Processing Record 15 of Set 9 | tornio
# Processing Record 16 of Set 9 | othonoi
# City not found. Skipping...
# Processing Record 17 of Set 9 | palmeira
# Processing Record 18 of Set 9 | fairfield
# Processing Record 19 of Set 9 | tutoia
# Processing Record 20 of Set 9 | pochutla
# Processing Record 21 of Set 9 | opuwo
# Processing Record 22 of Set 9 | omsukchan
# Processing Record 23 of Set 9 | asosa
# Processing Record 24 of Set 9 | jamame
# Processing Record 25 of Set 9 | luebo
# Processing Record 26 of Set 9 | moscow
# Processing Record 27 of Set 9 | bambanglipuro
# Processing Record 28 of Set 9 | soure
# Processing Record 29 of Set 9 | chernogorsk
# Processing Record 30 of Set 9 | necochea
# Processing Record 31 of Set 9 | sapao
# City not found. Skipping...
# Processing Record 32 of Set 9 | lorengau
# Processing Record 33 of Set 9 | ponferrada
# Processing Record 34 of Set 9 | mount isa
# Processing Record 35 of Set 9 | dauphin
# Processing Record 36 of Set 9 | manyana
# Processing Record 37 of Set 9 | alamos
# Processing Record 38 of Set 9 | half moon bay
# Processing Record 39 of Set 9 | shebalino
# Processing Record 40 of Set 9 | pangnirtung
# Processing Record 41 of Set 9 | paita
# Processing Record 42 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 9 | papara
# Processing Record 44 of Set 9 | pyay
# Processing Record 45 of Set 9 | storsteinnes
# Processing Record 46 of Set 9 | aktas
# Processing Record 47 of Set 9 | somovo
# Processing Record 48 of Set 9 | rubizhne
# Processing Record 49 of Set 9 | inhambane
# Processing Record 50 of Set 9 | kempele
# Processing Record 1 of Set 10 | luchegorsk
# Processing Record 2 of Set 10 | kuching
# Processing Record 3 of Set 10 | poros
# Processing Record 4 of Set 10 | mehamn
# Processing Record 5 of Set 10 | moryakovskiy zaton
# Processing Record 6 of Set 10 | fountain hills
# Processing Record 7 of Set 10 | oktyabrskiy
# Processing Record 8 of Set 10 | bathsheba
# Processing Record 9 of Set 10 | jonesboro
# Processing Record 10 of Set 10 | salto
# Processing Record 11 of Set 10 | muzhi
# Processing Record 12 of Set 10 | sibolga
# Processing Record 13 of Set 10 | maceio
# Processing Record 14 of Set 10 | marbella
# Processing Record 15 of Set 10 | nicolas bravo
# Processing Record 16 of Set 10 | samarai
# Processing Record 17 of Set 10 | honiara
# Processing Record 18 of Set 10 | ljungby
# Processing Record 19 of Set 10 | karagaylinskiy
# Processing Record 20 of Set 10 | guerrero negro
# Processing Record 21 of Set 10 | alta
# Processing Record 22 of Set 10 | sale
# Processing Record 23 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 10 | kidal
# Processing Record 25 of Set 10 | nizwa
# Processing Record 26 of Set 10 | mahenge
# Processing Record 27 of Set 10 | maltahohe
# Processing Record 28 of Set 10 | college
# Processing Record 29 of Set 10 | novobiryusinskiy
# Processing Record 30 of Set 10 | talcahuano
# Processing Record 31 of Set 10 | sherghati
# Processing Record 32 of Set 10 | ahipara
# Processing Record 33 of Set 10 | ballina
# Processing Record 34 of Set 10 | benguela
# Processing Record 35 of Set 10 | alyangula
# Processing Record 36 of Set 10 | bundaberg
# Processing Record 37 of Set 10 | sakaiminato
# Processing Record 38 of Set 10 | hambantota
# Processing Record 39 of Set 10 | serenje
# Processing Record 40 of Set 10 | hami
# Processing Record 41 of Set 10 | shingu
# Processing Record 42 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 10 | fonte boa
# Processing Record 44 of Set 10 | broken hill
# Processing Record 45 of Set 10 | port lincoln
# Processing Record 46 of Set 10 | kalemie
# Processing Record 47 of Set 10 | chowchilla
# Processing Record 48 of Set 10 | lokoja
# Processing Record 49 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 10 | khorixas
# Processing Record 1 of Set 11 | sabak
# Processing Record 2 of Set 11 | port hardy
# Processing Record 3 of Set 11 | dana point
# Processing Record 4 of Set 11 | ancud
# Processing Record 5 of Set 11 | xiuyan
# Processing Record 6 of Set 11 | north bend
# Processing Record 7 of Set 11 | brigantine
# Processing Record 8 of Set 11 | the valley
# Processing Record 9 of Set 11 | cap-haitien
# Processing Record 10 of Set 11 | paamiut
# Processing Record 11 of Set 11 | medvezhyegorsk
# Processing Record 12 of Set 11 | sangar
# Processing Record 13 of Set 11 | maragheh
# Processing Record 14 of Set 11 | shellbrook
# Processing Record 15 of Set 11 | vestmannaeyjar
# Processing Record 16 of Set 11 | puerto colombia
# Processing Record 17 of Set 11 | lichinga
# Processing Record 18 of Set 11 | taltal
# Processing Record 19 of Set 11 | ayan
# Processing Record 20 of Set 11 | hobyo
# Processing Record 21 of Set 11 | westport
# Processing Record 22 of Set 11 | baruun-urt
# Processing Record 23 of Set 11 | suoyarvi
# Processing Record 24 of Set 11 | changji
# Processing Record 25 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 11 | sinjar
# Processing Record 27 of Set 11 | pandharpur
# Processing Record 28 of Set 11 | qasigiannguit
# Processing Record 29 of Set 11 | huangmei
# Processing Record 30 of Set 11 | khani
# Processing Record 31 of Set 11 | kenmore
# Processing Record 32 of Set 11 | wanaka
# Processing Record 33 of Set 11 | port moresby
# Processing Record 34 of Set 11 | medeiros neto
# Processing Record 35 of Set 11 | marsh harbour
# Processing Record 36 of Set 11 | bilma
# Processing Record 37 of Set 11 | zavitinsk
# Processing Record 38 of Set 11 | karabanovo
# Processing Record 39 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 40 of Set 11 | san felipe
# Processing Record 41 of Set 11 | berlevag
# Processing Record 42 of Set 11 | beloha
# Processing Record 43 of Set 11 | santa cruz
# Processing Record 44 of Set 11 | sokol
# Processing Record 45 of Set 11 | tura
# Processing Record 46 of Set 11 | linxia
# Processing Record 47 of Set 11 | tateyama
# Processing Record 48 of Set 11 | shieli
# Processing Record 49 of Set 11 | tuktoyaktuk
# Processing Record 50 of Set 11 | brownsville
# Processing Record 1 of Set 12 | tessalit
# Processing Record 2 of Set 12 | natal
# Processing Record 3 of Set 12 | sistranda
# Processing Record 4 of Set 12 | mon
# Processing Record 5 of Set 12 | isangel
# Processing Record 6 of Set 12 | xianshuigu
# Processing Record 7 of Set 12 | miyako
# Processing Record 8 of Set 12 | nemuro
# Processing Record 9 of Set 12 | constitucion
# Processing Record 10 of Set 12 | manavalakurichi
# Processing Record 11 of Set 12 | san vicente de canete
# Processing Record 12 of Set 12 | kluang
# Processing Record 13 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 12 | shitanjing
# Processing Record 15 of Set 12 | cockburn town
# Processing Record 16 of Set 12 | terrace
# Processing Record 17 of Set 12 | maningrida
# Processing Record 18 of Set 12 | manacapuru
# Processing Record 19 of Set 12 | tsaratanana
# Processing Record 20 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 12 | punta de piedra
# Processing Record 22 of Set 12 | jodhpur
# Processing Record 23 of Set 12 | amahai
# Processing Record 24 of Set 12 | arequipa
# Processing Record 25 of Set 12 | pastos bons
# Processing Record 26 of Set 12 | kruisfontein
# Processing Record 27 of Set 12 | alofi
# Processing Record 28 of Set 12 | bardejov
# Processing Record 29 of Set 12 | fort saint james
# Processing Record 30 of Set 12 | lethem
# Processing Record 31 of Set 12 | mogadishu
# Processing Record 32 of Set 12 | antalaha
# Processing Record 33 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 12 | lixourion
# Processing Record 35 of Set 12 | buraydah
# Processing Record 36 of Set 12 | kevsala
# Processing Record 37 of Set 12 | iracoubo
# Processing Record 38 of Set 12 | baykit
# Processing Record 39 of Set 12 | ola
# Processing Record 40 of Set 12 | olinda
# Processing Record 41 of Set 12 | alice springs
# Processing Record 42 of Set 12 | kibaya
# Processing Record 43 of Set 12 | smithers
# Processing Record 44 of Set 12 | strezhevoy
# Processing Record 45 of Set 12 | uruzgan
# Processing Record 46 of Set 12 | sarishabari
# Processing Record 47 of Set 12 | bonavista
# Processing Record 48 of Set 12 | sindor
# Processing Record 49 of Set 12 | gat
# Processing Record 50 of Set 12 | port pirie
# Processing Record 1 of Set 13 | domna
# Processing Record 2 of Set 13 | dali
# Processing Record 3 of Set 13 | isoka
# Processing Record 4 of Set 13 | bayji
# Processing Record 5 of Set 13 | ahuimanu
# Processing Record 6 of Set 13 | sioux lookout
# Processing Record 7 of Set 13 | kotelnikovo
# Processing Record 8 of Set 13 | pechora
# Processing Record 9 of Set 13 | harrisburg
# Processing Record 10 of Set 13 | pavilosta
# Processing Record 11 of Set 13 | krasnoselkup
# Processing Record 12 of Set 13 | pontypool
# Processing Record 13 of Set 13 | mayumba
# Processing Record 14 of Set 13 | buchanan
# Processing Record 15 of Set 13 | balingasay
# Processing Record 16 of Set 13 | cayenne
# Processing Record 17 of Set 13 | wanning
# Processing Record 18 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 13 | manzhouli
# Processing Record 21 of Set 13 | zyryanka
# Processing Record 22 of Set 13 | neuquen
# Processing Record 23 of Set 13 | abu dhabi
# Processing Record 24 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 13 | talara
# Processing Record 26 of Set 13 | maryborough
# Processing Record 27 of Set 13 | rio grande
# Processing Record 28 of Set 13 | leiyang
# Processing Record 29 of Set 13 | muroto
# Processing Record 30 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 31 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 32 of Set 13 | tabuk
# Processing Record 33 of Set 13 | ixtapa
# Processing Record 34 of Set 13 | skibbereen
# Processing Record 35 of Set 13 | nerchinskiy zavod
# Processing Record 36 of Set 13 | san rafael
# Processing Record 37 of Set 13 | bell ville
# Processing Record 38 of Set 13 | lashio
# Processing Record 39 of Set 13 | vanavara
# Processing Record 40 of Set 13 | el naranjo
# Processing Record 41 of Set 13 | aksu
# Processing Record 42 of Set 13 | broome
# Processing Record 43 of Set 13 | torrevieja
# Processing Record 44 of Set 13 | eenhana
# Processing Record 45 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 13 | stornoway
# Processing Record 47 of Set 13 | paragominas
# Processing Record 48 of Set 13 | itaituba
# Processing Record 49 of Set 13 | khasan
# Processing Record 50 of Set 13 | vostochnyy
# Processing Record 1 of Set 14 | carrollton
# Processing Record 2 of Set 14 | nouadhibou
# Processing Record 3 of Set 14 | umm lajj
# Processing Record 4 of Set 14 | tanjong malim
# City not found. Skipping...
# Processing Record 5 of Set 14 | orocue
# Processing Record 6 of Set 14 | wewak
# Processing Record 7 of Set 14 | lavrentiya
# Processing Record 8 of Set 14 | avenal
# Processing Record 9 of Set 14 | trapani
# Processing Record 10 of Set 14 | tungor
# Processing Record 11 of Set 14 | arlit
# Processing Record 12 of Set 14 | luau
# Processing Record 13 of Set 14 | jiayuguan
# Processing Record 14 of Set 14 | dickson
# Processing Record 15 of Set 14 | khowai
# Processing Record 16 of Set 14 | galveston
# Processing Record 17 of Set 14 | bossangoa
# Processing Record 18 of Set 14 | carman
# Processing Record 19 of Set 14 | pierre
# Processing Record 20 of Set 14 | bilecik
# Processing Record 21 of Set 14 | vinstra
# Processing Record 22 of Set 14 | willowmore
# Processing Record 23 of Set 14 | wahiawa
# Processing Record 24 of Set 14 | meiganga
# Processing Record 25 of Set 14 | ust-tsilma
# Processing Record 26 of Set 14 | ongandjera
# Processing Record 27 of Set 14 | kawalu
# Processing Record 28 of Set 14 | topolobampo
# Processing Record 29 of Set 14 | krutinka
# Processing Record 30 of Set 14 | de-kastri
# Processing Record 31 of Set 14 | saku
# Processing Record 32 of Set 14 | tirlyanskiy
# Processing Record 33 of Set 14 | tucurui
# Processing Record 34 of Set 14 | qiongshan
# Processing Record 35 of Set 14 | rocha
# Processing Record 36 of Set 14 | malakal
# Processing Record 37 of Set 14 | adrar
# Processing Record 38 of Set 14 | raudeberg
# Processing Record 39 of Set 14 | archidona
# Processing Record 40 of Set 14 | rabo de peixe
# Processing Record 41 of Set 14 | dickinson
# Processing Record 42 of Set 14 | port blair
# Processing Record 43 of Set 14 | geilo
# Processing Record 44 of Set 14 | skjervoy
# Processing Record 45 of Set 14 | qunduz
# Processing Record 46 of Set 14 | urumqi
# Processing Record 47 of Set 14 | mantua
# Processing Record 48 of Set 14 | flin flon
# Processing Record 49 of Set 14 | great yarmouth
# Processing Record 50 of Set 14 | port augusta
# Processing Record 1 of Set 15 | payakumbuh
# Processing Record 2 of Set 15 | chimbote
# Processing Record 3 of Set 15 | road town
# Processing Record 4 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 15 | ayagoz
# Processing Record 6 of Set 15 | kiruna
# Processing Record 7 of Set 15 | ambon
# Processing Record 8 of Set 15 | ruwi
# Processing Record 9 of Set 15 | fortuna
# Processing Record 10 of Set 15 | ilo
# Processing Record 11 of Set 15 | nome
# Processing Record 12 of Set 15 | vrangel
# Processing Record 13 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 14 of Set 15 | the pas
# Processing Record 15 of Set 15 | beihai
# Processing Record 16 of Set 15 | osa
# Processing Record 17 of Set 15 | diapaga
# Processing Record 18 of Set 15 | hervey bay
# Processing Record 19 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 20 of Set 15 | chkalovsk
# Processing Record 21 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 15 | massakory
# Processing Record 23 of Set 15 | port-cartier
# Processing Record 24 of Set 15 | bar harbor
# Processing Record 25 of Set 15 | borazjan
# Processing Record 26 of Set 15 | san juan
# Processing Record 27 of Set 15 | dhidhdhoo
# Processing Record 28 of Set 15 | saint anthony
# Processing Record 29 of Set 15 | zhigansk
# Processing Record 30 of Set 15 | saint-joseph
# Processing Record 31 of Set 15 | maun
# Processing Record 32 of Set 15 | chara
# Processing Record 33 of Set 15 | banda aceh
# Processing Record 34 of Set 15 | pangai
# Processing Record 35 of Set 15 | meulaboh
# Processing Record 36 of Set 15 | ponta pora
# Processing Record 37 of Set 15 | reconquista
# Processing Record 38 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 39 of Set 15 | san jose
# Processing Record 40 of Set 15 | omboue
# Processing Record 41 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 42 of Set 15 | vangaindrano
# Processing Record 43 of Set 15 | acarau
# Processing Record 44 of Set 15 | prince rupert
# Processing Record 45 of Set 15 | hamilton
# Processing Record 46 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 47 of Set 15 | ternate
# Processing Record 48 of Set 15 | suez
# Processing Record 49 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 50 of Set 15 | mayari
# City not found. Skipping...
# Processing Record 1 of Set 16 | ayolas
# Processing Record 2 of Set 16 | copiapo
# Processing Record 3 of Set 16 | nyrob
# Processing Record 4 of Set 16 | pamplona
# Processing Record 5 of Set 16 | nkayi
# Processing Record 6 of Set 16 | gurgan
# City not found. Skipping...
# Processing Record 7 of Set 16 | gonbad-e qabus
# Processing Record 8 of Set 16 | pyinmana
# Processing Record 9 of Set 16 | kahului
# Processing Record 10 of Set 16 | houston
# Processing Record 11 of Set 16 | geraldton
# Processing Record 12 of Set 16 | vicksburg
# Processing Record 13 of Set 16 | kombotion
# City not found. Skipping...
# Processing Record 14 of Set 16 | chardara
# Processing Record 15 of Set 16 | kropotkin
# Processing Record 16 of Set 16 | port-gentil
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data2
# Out:
# [{'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 69.58,
#   'Humidity': 66,
#   'Cloudiness': 72,
#   'Wind Speed': 13.65,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 41.25,
#   'Humidity': 91,
#   'Cloudiness': 20,
#   'Wind Speed': 1.14,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 62.67,
#   'Humidity': 89,
#   'Cloudiness': 23,
#   'Wind Speed': 1.68,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'San Matias',
#   'Lat': -16.3667,
#   'Lng': -58.4,
#   'Max Temp': 83.97,
#   'Humidity': 26,
#   'Cloudiness': 35,
#   'Wind Speed': 4.38,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Moorhead',
#   'Lat': 46.8739,
#   'Lng': -96.7676,
#   'Max Temp': 85.98,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Uige',
#   'Lat': -7.6087,
#   'Lng': 15.0613,
#   'Max Temp': 66.49,
#   'Humidity': 71,
#   'Cloudiness': 61,
#   'Wind Speed': 2.75,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Pericos',
#   'Lat': 25.05,
#   'Lng': -107.7,
#   'Max Temp': 103.91,
#   'Humidity': 43,
#   'Cloudiness': 15,
#   'Wind Speed': 13.35,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 84.52,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 54.21,
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 11.43,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 62.53,
#   'Humidity': 91,
#   'Cloudiness': 92,
#   'Wind Speed': 2.1,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bara',
#   'Lat': 10.3744,
#   'Lng': 10.7288,
#   'Max Temp': 74.62,
#   'Humidity': 86,
#   'Cloudiness': 67,
#   'Wind Speed': 8.41,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 74.41,
#   'Humidity': 80,
#   'Cloudiness': 93,
#   'Wind Speed': 22.46,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 41.81,
#   'Humidity': 82,
#   'Cloudiness': 88,
#   'Wind Speed': 8.1,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 41.49,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.58,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 53.15,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 3.98,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tazovskiy',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': 43.48,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 84.27,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'GA',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 57.63,
#   'Humidity': 80,
#   'Cloudiness': 66,
#   'Wind Speed': 9.8,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 42.35,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 17.27,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 91.51,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 40.91,
#   'Humidity': 96,
#   'Cloudiness': 2,
#   'Wind Speed': 3.76,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Dalby',
#   'Lat': -27.1833,
#   'Lng': 151.2667,
#   'Max Temp': 53.98,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 82.8,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 18.79,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 62.49,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Anloga',
#   'Lat': 5.7947,
#   'Lng': 0.8973,
#   'Max Temp': 75.25,
#   'Humidity': 80,
#   'Cloudiness': 12,
#   'Wind Speed': 12.93,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 32.11,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 20.71,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 52.3,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 13.42,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Anjozorobe',
#   'Lat': -18.4,
#   'Lng': 47.8667,
#   'Max Temp': 50.97,
#   'Humidity': 93,
#   'Cloudiness': 85,
#   'Wind Speed': 6.78,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 71.71,
#   'Humidity': 81,
#   'Cloudiness': 3,
#   'Wind Speed': 7.76,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kristiansund',
#   'Lat': 63.1115,
#   'Lng': 7.732,
#   'Max Temp': 52.45,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 57.58,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 7.81,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Alta Floresta',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 80.33,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 1.07,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 45.16,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 13.69,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 29.86,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'GA',
#   'Weather Description': 'heavy snow'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 71.11,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 12.95,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 53.58,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'GA',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 31.95,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 54.37,
#   'Humidity': 90,
#   'Cloudiness': 93,
#   'Wind Speed': 7,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Synya',
#   'Lat': 65.3718,
#   'Lng': 58.0387,
#   'Max Temp': 45.03,
#   'Humidity': 69,
#   'Cloudiness': 5,
#   'Wind Speed': 6.02,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 47.77,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 9.57,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sabi',
#   'Lat': 13.2333,
#   'Lng': -14.2,
#   'Max Temp': 75.38,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Country': 'GA',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Boyolangu',
#   'Lat': -8.1181,
#   'Lng': 111.8935,
#   'Max Temp': 74.19,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 49.68,
#   'Humidity': 62,
#   'Cloudiness': 28,
#   'Wind Speed': 11.43,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 46.74,
#   'Humidity': 69,
#   'Cloudiness': 11,
#   'Wind Speed': 7.96,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 78.96,
#   'Humidity': 78,
#   'Cloudiness': 45,
#   'Wind Speed': 14.34,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 73.99,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 9.55,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Waipawa',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 45.79,
#   'Humidity': 73,
#   'Cloudiness': 98,
#   'Wind Speed': 13.51,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Collie',
#   'Lat': -33.3667,
#   'Lng': 116.15,
#   'Max Temp': 49.98,
#   'Humidity': 95,
#   'Cloudiness': 50,
#   'Wind Speed': 2.77,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Estacion Coahuila',
#   'Lat': 32.1939,
#   'Lng': -115.0017,
#   'Max Temp': 111.47,
#   'Humidity': 16,
#   'Cloudiness': 99,
#   'Wind Speed': 7.27,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.4,
#   'Humidity': 73,
#   'Cloudiness': 14,
#   'Wind Speed': 16.15,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Berdigestyakh',
#   'Lat': 62.0989,
#   'Lng': 126.6992,
#   'Max Temp': 62.96,
#   'Humidity': 95,
#   'Cloudiness': 81,
#   'Wind Speed': 6.13,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Huarmey',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 64.38,
#   'Humidity': 79,
#   'Cloudiness': 22,
#   'Wind Speed': 10.56,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 63.82,
#   'Humidity': 52,
#   'Cloudiness': 98,
#   'Wind Speed': 8.01,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 69.22,
#   'Humidity': 67,
#   'Cloudiness': 89,
#   'Wind Speed': 17.22,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Newport',
#   'Lat': 51.5877,
#   'Lng': -2.9984,
#   'Max Temp': 68.45,
#   'Humidity': 70,
#   'Cloudiness': 88,
#   'Wind Speed': 4.79,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 69.26,
#   'Humidity': 67,
#   'Cloudiness': 81,
#   'Wind Speed': 16.98,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 35.55,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 9.15,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 91.36,
#   'Humidity': 52,
#   'Cloudiness': 25,
#   'Wind Speed': 1.01,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': 55.85,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tabou',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 75.43,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 73.62,
#   'Humidity': 90,
#   'Cloudiness': 32,
#   'Wind Speed': 18.66,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bud',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 90.93,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 7.67,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Yarmouth',
#   'Lat': 41.7057,
#   'Lng': -70.2286,
#   'Max Temp': 81.61,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'GA',
#   'Weather Description': 'mist'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 58.91,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 5.06,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 50.31,
#   'Humidity': 95,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lokachi',
#   'Lat': 50.737,
#   'Lng': 24.6494,
#   'Max Temp': 64.74,
#   'Humidity': 84,
#   'Cloudiness': 7,
#   'Wind Speed': 4.23,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.76,
#   'Humidity': 89,
#   'Cloudiness': 54,
#   'Wind Speed': 5.99,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Balykshi',
#   'Lat': 47.0667,
#   'Lng': 51.8667,
#   'Max Temp': 75.2,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 4.47,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 83.05,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Atambua',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 68.76,
#   'Humidity': 87,
#   'Cloudiness': 95,
#   'Wind Speed': 6.85,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 52.2,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 9.28,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Puerto Palomas',
#   'Lat': 31.7667,
#   'Lng': -107.6167,
#   'Max Temp': 100.94,
#   'Humidity': 15,
#   'Cloudiness': 36,
#   'Wind Speed': 5.7,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 80.62,
#   'Humidity': 87,
#   'Cloudiness': 46,
#   'Wind Speed': 14.85,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 57.09,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 43.92,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 2.51,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Singapore',
#   'Lat': 1.2897,
#   'Lng': 103.8501,
#   'Max Temp': 78.84,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Khakhea',
#   'Lat': -24.6895,
#   'Lng': 23.494,
#   'Max Temp': 59.99,
#   'Humidity': 45,
#   'Cloudiness': 52,
#   'Wind Speed': 6.76,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 44.33,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 11.95,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 82.17,
#   'Humidity': 77,
#   'Cloudiness': 97,
#   'Wind Speed': 2.84,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Panguma',
#   'Lat': 8.1833,
#   'Lng': -11.1333,
#   'Max Temp': 70,
#   'Humidity': 99,
#   'Cloudiness': 85,
#   'Wind Speed': 2.75,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Inirida',
#   'Lat': 3.8653,
#   'Lng': -67.9239,
#   'Max Temp': 77.22,
#   'Humidity': 96,
#   'Cloudiness': 94,
#   'Wind Speed': 2.21,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Casper',
#   'Lat': 42.8666,
#   'Lng': -106.3131,
#   'Max Temp': 93.81,
#   'Humidity': 15,
#   'Cloudiness': 1,
#   'Wind Speed': 5.01,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 64.18,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 5.7,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Jeremie',
#   'Lat': 18.65,
#   'Lng': -74.1167,
#   'Max Temp': 84.97,
#   'Humidity': 67,
#   'Cloudiness': 60,
#   'Wind Speed': 5.08,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Eureka',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Max Temp': 67.19,
#   'Humidity': 79,
#   'Cloudiness': 68,
#   'Wind Speed': 8.01,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 75.2,
#   'Humidity': 84,
#   'Cloudiness': 93,
#   'Wind Speed': 8.88,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Falmouth',
#   'Lat': 50.1544,
#   'Lng': -5.0711,
#   'Max Temp': 59.58,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 54.41,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 4.07,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 77.32,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 25.61,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Barra',
#   'Lat': -11.0894,
#   'Lng': -43.1417,
#   'Max Temp': 76.24,
#   'Humidity': 43,
#   'Cloudiness': 23,
#   'Wind Speed': 4.79,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 80.51,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.12,
#   'Country': 'GA',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 81.57,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 11.18,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Lengshuitan',
#   'Lat': 26.4111,
#   'Lng': 111.5956,
#   'Max Temp': 77.54,
#   'Humidity': 88,
#   'Cloudiness': 22,
#   'Wind Speed': 5.93,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Botwood',
#   'Lat': 49.1499,
#   'Lng': -55.3482,
#   'Max Temp': 74.89,
#   'Humidity': 58,
#   'Cloudiness': 49,
#   'Wind Speed': 7.49,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 41.16,
#   'Humidity': 78,
#   'Cloudiness': 80,
#   'Wind Speed': 0.98,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sanbu',
#   'Lat': 33.4594,
#   'Lng': 119.1453,
#   'Max Temp': 75.06,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 51.26,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 14.41,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 51.13,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 8.68,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Aktau',
#   'Lat': 43.65,
#   'Lng': 51.2,
#   'Max Temp': 77.58,
#   'Humidity': 53,
#   'Cloudiness': 68,
#   'Wind Speed': 21.59,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 54.82,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.66,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Orlik',
#   'Lat': 52.5178,
#   'Lng': 99.825,
#   'Max Temp': 47.71,
#   'Humidity': 86,
#   'Cloudiness': 89,
#   'Wind Speed': 1.01,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 59.88,
#   'Humidity': 84,
#   'Cloudiness': 46,
#   'Wind Speed': 2.71,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Cestas',
#   'Lat': 44.7435,
#   'Lng': -0.6791,
#   'Max Temp': 74.86,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 53.91,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 61.7,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 3.13,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Charters Towers',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 57.02,
#   'Humidity': 82,
#   'Cloudiness': 2,
#   'Wind Speed': 6.85,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Pirovskoye',
#   'Lat': 57.6267,
#   'Lng': 92.2658,
#   'Max Temp': 55.65,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 80.89,
#   'Humidity': 91,
#   'Cloudiness': 20,
#   'Wind Speed': 1.14,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 74.79,
#   'Humidity': 90,
#   'Cloudiness': 85,
#   'Wind Speed': 4.52,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Amazar',
#   'Lat': 53.858,
#   'Lng': 120.875,
#   'Max Temp': 67.03,
#   'Humidity': 87,
#   'Cloudiness': 60,
#   'Wind Speed': 2.33,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 46.51,
#   'Humidity': 86,
#   'Cloudiness': 80,
#   'Wind Speed': 11.05,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 54.25,
#   'Humidity': 85,
#   'Cloudiness': 95,
#   'Wind Speed': 5.03,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 81.55,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 59.54,
#   'Humidity': 95,
#   'Cloudiness': 37,
#   'Wind Speed': 2.08,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Zaoyang',
#   'Lat': 32.1272,
#   'Lng': 112.7542,
#   'Max Temp': 79.21,
#   'Humidity': 92,
#   'Cloudiness': 93,
#   'Wind Speed': 11.03,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 50.61,
#   'Humidity': 89,
#   'Cloudiness': 35,
#   'Wind Speed': 1.92,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 99.18,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Challans',
#   'Lat': 46.8436,
#   'Lng': -1.8749,
#   'Max Temp': 66.4,
#   'Humidity': 85,
#   'Cloudiness': 8,
#   'Wind Speed': 8.9,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 42.53,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'GA',
#   'Weather Description': 'fog'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 76.14,
#   'Humidity': 43,
#   'Cloudiness': 28,
#   'Wind Speed': 5.79,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 64.9,
#   'Humidity': 78,
#   'Cloudiness': 16,
#   'Wind Speed': 5.01,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Gunzenhausen',
#   'Lat': 49.1,
#   'Lng': 10.75,
#   'Max Temp': 68.49,
#   'Humidity': 69,
#   'Cloudiness': 4,
#   'Wind Speed': 2.91,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'San Luis',
#   'Lat': -33.295,
#   'Lng': -66.3356,
#   'Max Temp': 58.39,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 10.04,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 54.91,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mayo',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 94.35,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 85.15,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 4.88,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Imbituba',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp': 69.1,
#   'Humidity': 87,
#   'Cloudiness': 14,
#   'Wind Speed': 10.16,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 43.25,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 9.55,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 81.59,
#   'Humidity': 74,
#   'Cloudiness': 81,
#   'Wind Speed': 5.77,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 102.31,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 77.09,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pitogo',
#   'Lat': 13.7847,
#   'Lng': 122.0881,
#   'Max Temp': 78.21,
#   'Humidity': 89,
#   'Cloudiness': 26,
#   'Wind Speed': 3.13,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 79.02,
#   'Humidity': 86,
#   'Cloudiness': 52,
#   'Wind Speed': 3.51,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Gelemso',
#   'Lat': 8.8167,
#   'Lng': 40.5167,
#   'Max Temp': 59.95,
#   'Humidity': 83,
#   'Cloudiness': 66,
#   'Wind Speed': 5.06,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Lufilufi',
#   'Lat': -13.8745,
#   'Lng': -171.5986,
#   'Max Temp': 83.79,
#   'Humidity': 73,
#   'Cloudiness': 30,
#   'Wind Speed': 17,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 76.14,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 9.1,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Beidao',
#   'Lat': 34.5686,
#   'Lng': 105.8933,
#   'Max Temp': 60.08,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.16,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 62.65,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Boysun',
#   'Lat': 38.2061,
#   'Lng': 67.1986,
#   'Max Temp': 81.5,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 4.92,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Zhezkazgan',
#   'Lat': 47.8043,
#   'Lng': 67.7144,
#   'Max Temp': 75.63,
#   'Humidity': 38,
#   'Cloudiness': 17,
#   'Wind Speed': 9.69,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 67.78,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 13.15,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Severodvinsk',
#   'Lat': 64.5635,
#   'Lng': 39.8302,
#   'Max Temp': 57.31,
#   'Humidity': 91,
#   'Cloudiness': 9,
#   'Wind Speed': 5.64,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Vagur',
#   'Lat': 61.4732,
#   'Lng': -6.8119,
#   'Max Temp': 49.89,
#   'Humidity': 86,
#   'Cloudiness': 15,
#   'Wind Speed': 1.99,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 45.12,
#   'Humidity': 59,
#   'Cloudiness': 98,
#   'Wind Speed': 6.13,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bontang',
#   'Lat': 0.1333,
#   'Lng': 117.5,
#   'Max Temp': 78.1,
#   'Humidity': 85,
#   'Cloudiness': 73,
#   'Wind Speed': 1.61,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Giyani',
#   'Lat': -23.3025,
#   'Lng': 30.7187,
#   'Max Temp': 60.91,
#   'Humidity': 81,
#   'Cloudiness': 9,
#   'Wind Speed': 3.24,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 73.78,
#   'Humidity': 85,
#   'Cloudiness': 48,
#   'Wind Speed': 2.46,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 74.97,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 6.42,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Rodrigues Alves',
#   'Lat': -7.738,
#   'Lng': -72.6509,
#   'Max Temp': 84.2,
#   'Humidity': 52,
#   'Cloudiness': 24,
#   'Wind Speed': 1.79,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Coralville',
#   'Lat': 41.6764,
#   'Lng': -91.5805,
#   'Max Temp': 90.9,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ozinki',
#   'Lat': 51.1786,
#   'Lng': 49.6769,
#   'Max Temp': 63.39,
#   'Humidity': 81,
#   'Cloudiness': 70,
#   'Wind Speed': 5.99,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Hue',
#   'Lat': 16.4667,
#   'Lng': 107.6,
#   'Max Temp': 77.11,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Talca',
#   'Lat': -35.4333,
#   'Lng': -71.6667,
#   'Max Temp': 53.26,
#   'Humidity': 86,
#   'Cloudiness': 25,
#   'Wind Speed': 3.6,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Eirunepe',
#   'Lat': -6.6603,
#   'Lng': -69.8736,
#   'Max Temp': 83.46,
#   'Humidity': 59,
#   'Cloudiness': 66,
#   'Wind Speed': 1.86,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 53.64,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 25.55,
#   'Country': 'GA',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.12,
#   'Humidity': 74,
#   'Cloudiness': 62,
#   'Wind Speed': 5.91,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 49.75,
#   'Humidity': 78,
#   'Cloudiness': 9,
#   'Wind Speed': 6.17,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Betioky',
#   'Lat': -23.7167,
#   'Lng': 44.3833,
#   'Max Temp': 64.8,
#   'Humidity': 62,
#   'Cloudiness': 33,
#   'Wind Speed': 6.13,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 81.28,
#   'Humidity': 89,
#   'Cloudiness': 78,
#   'Wind Speed': 16.96,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 46.42,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 26.46,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 65.21,
#   'Humidity': 84,
#   'Cloudiness': 52,
#   'Wind Speed': 13.27,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Avigliana',
#   'Lat': 45.0771,
#   'Lng': 7.3986,
#   'Max Temp': 83.79,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 6.51,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Yining',
#   'Lat': 29.0361,
#   'Lng': 114.5636,
#   'Max Temp': 77.92,
#   'Humidity': 89,
#   'Cloudiness': 92,
#   'Wind Speed': 2.01,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Zafra',
#   'Lat': 38.4167,
#   'Lng': -6.4167,
#   'Max Temp': 81.63,
#   'Humidity': 24,
#   'Cloudiness': 74,
#   'Wind Speed': 6.2,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 51.1,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 42.91,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 17.9,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 67.75,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Tarpon Springs',
#   'Lat': 28.1461,
#   'Lng': -82.7568,
#   'Max Temp': 91.96,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Shengjin',
#   'Lat': 41.8136,
#   'Lng': 19.5939,
#   'Max Temp': 75.7,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 48.79,
#   'Humidity': 90,
#   'Cloudiness': 93,
#   'Wind Speed': 1.01,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 73.89,
#   'Humidity': 73,
#   'Cloudiness': 87,
#   'Wind Speed': 4,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mahoba',
#   'Lat': 25.2833,
#   'Lng': 79.8667,
#   'Max Temp': 81.39,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 5.93,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Miri',
#   'Lat': 4.4148,
#   'Lng': 114.0089,
#   'Max Temp': 74.7,
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 6.58,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 71.78,
#   'Humidity': 71,
#   'Cloudiness': 87,
#   'Wind Speed': 5.23,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Innisfail',
#   'Lat': -17.5333,
#   'Lng': 146.0333,
#   'Max Temp': 65.7,
#   'Humidity': 86,
#   'Cloudiness': 6,
#   'Wind Speed': 4.9,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Dasoguz',
#   'Lat': 41.8363,
#   'Lng': 59.9666,
#   'Max Temp': 92.19,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 7.99,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Taveta',
#   'Lat': -3.3963,
#   'Lng': 37.6736,
#   'Max Temp': 65.3,
#   'Humidity': 78,
#   'Cloudiness': 77,
#   'Wind Speed': 5.35,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Dalvik',
#   'Lat': 65.9702,
#   'Lng': -18.5286,
#   'Max Temp': 52.39,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 75.09,
#   'Humidity': 57,
#   'Cloudiness': 96,
#   'Wind Speed': 6.51,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 50.25,
#   'Humidity': 75,
#   'Cloudiness': 2,
#   'Wind Speed': 9.75,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 71.46,
#   'Humidity': 51,
#   'Cloudiness': 87,
#   'Wind Speed': 6.98,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 52.25,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 7.38,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dumka',
#   'Lat': 24.2667,
#   'Lng': 87.25,
#   'Max Temp': 81.5,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.03,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chadiza',
#   'Lat': -14.0678,
#   'Lng': 32.4392,
#   'Max Temp': 58.82,
#   'Humidity': 65,
#   'Cloudiness': 26,
#   'Wind Speed': 3.4,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Praya',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 75.94,
#   'Humidity': 84,
#   'Cloudiness': 85,
#   'Wind Speed': 7.02,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hackettstown',
#   'Lat': 40.854,
#   'Lng': -74.8291,
#   'Max Temp': 94.46,
#   'Humidity': 49,
#   'Cloudiness': 2,
#   'Wind Speed': 5.75,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 53.37,
#   'Humidity': 78,
#   'Cloudiness': 66,
#   'Wind Speed': 17.49,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 61.02,
#   'Humidity': 75,
#   'Cloudiness': 51,
#   'Wind Speed': 17.31,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 97.16,
#   'Humidity': 44,
#   'Cloudiness': 17,
#   'Wind Speed': 19.46,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 51.82,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Axim',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 73.92,
#   'Humidity': 74,
#   'Cloudiness': 43,
#   'Wind Speed': 6.89,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Tarare',
#   'Lat': 45.8976,
#   'Lng': 4.4327,
#   'Max Temp': 72.93,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 1.88,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Mugla',
#   'Lat': 37.2303,
#   'Lng': 28.3557,
#   'Max Temp': 65.97,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 7.25,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 45.32,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 13.76,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ribeira Brava',
#   'Lat': 32.65,
#   'Lng': -17.0667,
#   'Max Temp': 71.71,
#   'Humidity': 83,
#   'Cloudiness': 3,
#   'Wind Speed': 7.72,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Abay',
#   'Lat': 49.6311,
#   'Lng': 72.8539,
#   'Max Temp': 53.98,
#   'Humidity': 61,
#   'Cloudiness': 47,
#   'Wind Speed': 2.46,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 51.03,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 10.09,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Shar',
#   'Lat': 49.5886,
#   'Lng': 81.0453,
#   'Max Temp': 66.96,
#   'Humidity': 87,
#   'Cloudiness': 84,
#   'Wind Speed': 7.02,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 79.52,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 86.18,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 58.93,
#   'Humidity': 77,
#   'Cloudiness': 3,
#   'Wind Speed': 6.69,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bom Jesus',
#   'Lat': -9.0744,
#   'Lng': -44.3586,
#   'Max Temp': 78.62,
#   'Humidity': 35,
#   'Cloudiness': 22,
#   'Wind Speed': 5.19,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Salina',
#   'Lat': 38.8403,
#   'Lng': -97.6114,
#   'Max Temp': 103.01,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 85.41,
#   'Humidity': 69,
#   'Cloudiness': 3,
#   'Wind Speed': 15.95,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Khanpur',
#   'Lat': 28.6453,
#   'Lng': 70.6567,
#   'Max Temp': 84.79,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'GA',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 49.69,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 7.18,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 47.44,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sumbawanga',
#   'Lat': -7.9667,
#   'Lng': 31.6167,
#   'Max Temp': 57.7,
#   'Humidity': 63,
#   'Cloudiness': 83,
#   'Wind Speed': 4.5,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ouesso',
#   'Lat': 1.6136,
#   'Lng': 16.0517,
#   'Max Temp': 70.63,
#   'Humidity': 97,
#   'Cloudiness': 90,
#   'Wind Speed': 1.63,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 47.71,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 6.49,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Impfondo',
#   'Lat': 1.6381,
#   'Lng': 18.0667,
#   'Max Temp': 71.82,
#   'Humidity': 97,
#   'Cloudiness': 90,
#   'Wind Speed': 2.44,
#   'Country': 'GA',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Havre-Saint-Pierre',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 62.96,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Xiamen',
#   'Lat': 24.4798,
#   'Lng': 118.0819,
#   'Max Temp': 83.25,
#   'Humidity': 84,
#   'Cloudiness': 5,
#   'Wind Speed': 4.63,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Aripuana',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 83.12,
#   'Humidity': 43,
#   'Cloudiness': 9,
#   'Wind Speed': 1.23,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Nalut',
#   'Lat': 30.3333,
#   'Lng': 10.85,
#   'Max Temp': 83.97,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 10.4,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Yerofey Pavlovich',
#   'Lat': 53.9667,
#   'Lng': 121.9667,
#   'Max Temp': 65.59,
#   'Humidity': 89,
#   'Cloudiness': 39,
#   'Wind Speed': 1.99,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 44.08,
#   'Humidity': 88,
#   'Cloudiness': 96,
#   'Wind Speed': 2.64,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 87.62,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 66.79,
#   'Humidity': 38,
#   'Cloudiness': 83,
#   'Wind Speed': 12.66,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mongo',
#   'Lat': 12.1844,
#   'Lng': 18.693,
#   'Max Temp': 80.74,
#   'Humidity': 72,
#   'Cloudiness': 98,
#   'Wind Speed': 2.06,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 59.4,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bam',
#   'Lat': 29.106,
#   'Lng': 58.357,
#   'Max Temp': 91.49,
#   'Humidity': 17,
#   'Cloudiness': 20,
#   'Wind Speed': 6.55,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 74.17,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 16.24,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gorontalo',
#   'Lat': 0.5412,
#   'Lng': 123.0595,
#   'Max Temp': 73.58,
#   'Humidity': 94,
#   'Cloudiness': 18,
#   'Wind Speed': 2.26,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Houma',
#   'Lat': 29.5958,
#   'Lng': -90.7195,
#   'Max Temp': 84.99,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 59.22,
#   'Humidity': 78,
#   'Cloudiness': 13,
#   'Wind Speed': 6.64,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Ambovombe',
#   'Lat': -25.1667,
#   'Lng': 46.0833,
#   'Max Temp': 66.7,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 2.8,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 78.53,
#   'Humidity': 70,
#   'Cloudiness': 95,
#   'Wind Speed': 19.35,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sorong',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 77.97,
#   'Humidity': 89,
#   'Cloudiness': 15,
#   'Wind Speed': 10.83,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Bulawayo',
#   'Lat': -20.15,
#   'Lng': 28.5833,
#   'Max Temp': 54.43,
#   'Humidity': 76,
#   'Cloudiness': 55,
#   'Wind Speed': 8.95,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Yumen',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 67.15,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 7.83,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 72.16,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 4.23,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 71.37,
#   'Humidity': 86,
#   'Cloudiness': 48,
#   'Wind Speed': 2.51,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Ianca',
#   'Lat': 45.1333,
#   'Lng': 27.45,
#   'Max Temp': 67.57,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 5.61,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kontagora',
#   'Lat': 10.3999,
#   'Lng': 5.4695,
#   'Max Temp': 74.66,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.1,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dire Dawa',
#   'Lat': 9.5931,
#   'Lng': 41.8661,
#   'Max Temp': 72.46,
#   'Humidity': 61,
#   'Cloudiness': 39,
#   'Wind Speed': 18.66,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Tiznit',
#   'Lat': 29.5833,
#   'Lng': -9.5,
#   'Max Temp': 89.35,
#   'Humidity': 21,
#   'Cloudiness': 30,
#   'Wind Speed': 2.33,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Rio Pardo De Minas',
#   'Lat': -15.6097,
#   'Lng': -42.5397,
#   'Max Temp': 65.73,
#   'Humidity': 49,
#   'Cloudiness': 8,
#   'Wind Speed': 5.03,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ugoofaaru',
# ...
#   'Lat': -17.8833,
#   'Lng': 15.0667,
#   'Max Temp': 61,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kawalu',
#   'Lat': -7.3817,
#   'Lng': 108.2082,
#   'Max Temp': 71.58,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Topolobampo',
#   'Lat': 25.6,
#   'Lng': -109.05,
#   'Max Temp': 96.71,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Krutinka',
#   'Lat': 56.0055,
#   'Lng': 71.5113,
#   'Max Temp': 54.45,
#   'Humidity': 98,
#   'Cloudiness': 53,
#   'Wind Speed': 8.9,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'De-Kastri',
#   'Lat': 51.4667,
#   'Lng': 140.7833,
#   'Max Temp': 56.88,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saku',
#   'Lat': 36.2167,
#   'Lng': 138.4833,
#   'Max Temp': 71.76,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 1.66,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tirlyanskiy',
#   'Lat': 54.2109,
#   'Lng': 58.5806,
#   'Max Temp': 50.65,
#   'Humidity': 95,
#   'Cloudiness': 79,
#   'Wind Speed': 2.86,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tucurui',
#   'Lat': -3.7661,
#   'Lng': -49.6725,
#   'Max Temp': 78.19,
#   'Humidity': 62,
#   'Cloudiness': 38,
#   'Wind Speed': 3.76,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Qiongshan',
#   'Lat': 20.0058,
#   'Lng': 110.3542,
#   'Max Temp': 76.98,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 49.24,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.6,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Malakal',
#   'Lat': 9.5334,
#   'Lng': 31.6605,
#   'Max Temp': 71.85,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.93,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 93.76,
#   'Humidity': 30,
#   'Cloudiness': 88,
#   'Wind Speed': 0.69,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Raudeberg',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 52.47,
#   'Humidity': 82,
#   'Cloudiness': 67,
#   'Wind Speed': 10.69,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Archidona',
#   'Lat': 37.0965,
#   'Lng': -4.3887,
#   'Max Temp': 72.41,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 7.25,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Rabo De Peixe',
#   'Lat': 37.8,
#   'Lng': -25.5833,
#   'Max Temp': 74.28,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Dickinson',
#   'Lat': 29.4608,
#   'Lng': -95.0513,
#   'Max Temp': 99.09,
#   'Humidity': 63,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 78.84,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'GA',
#   'Weather Description': 'mist'},
#  {'City': 'Geilo',
#   'Lat': 60.5333,
#   'Lng': 8.2076,
#   'Max Temp': 54.39,
#   'Humidity': 74,
#   'Cloudiness': 78,
#   'Wind Speed': 7.49,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Skjervoy',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 55.4,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Qunduz',
#   'Lat': 36.729,
#   'Lng': 68.857,
#   'Max Temp': 90.28,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 5.59,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Urumqi',
#   'Lat': 43.801,
#   'Lng': 87.6005,
#   'Max Temp': 68.95,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Mantua',
#   'Lat': 45.1667,
#   'Lng': 10.7833,
#   'Max Temp': 85.24,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 69.64,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Great Yarmouth',
#   'Lat': 52.6083,
#   'Lng': 1.7305,
#   'Max Temp': 61.45,
#   'Humidity': 80,
#   'Cloudiness': 25,
#   'Wind Speed': 7.49,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Port Augusta',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 50.83,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6.71,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Payakumbuh',
#   'Lat': -0.2202,
#   'Lng': 100.6308,
#   'Max Temp': 69.08,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 1.45,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chimbote',
#   'Lat': -9.0853,
#   'Lng': -78.5783,
#   'Max Temp': 63.48,
#   'Humidity': 80,
#   'Cloudiness': 69,
#   'Wind Speed': 10.45,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Road Town',
#   'Lat': 18.4167,
#   'Lng': -64.6167,
#   'Max Temp': 82.49,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Ayagoz',
#   'Lat': 47.9714,
#   'Lng': 80.4392,
#   'Max Temp': 66.15,
#   'Humidity': 47,
#   'Cloudiness': 73,
#   'Wind Speed': 7.02,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kiruna',
#   'Lat': 67.8557,
#   'Lng': 20.2251,
#   'Max Temp': 50.92,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ambon',
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp': 76.23,
#   'Humidity': 16,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Ruwi',
#   'Lat': 23.5996,
#   'Lng': 58.5507,
#   'Max Temp': 85.69,
#   'Humidity': 71,
#   'Cloudiness': 15,
#   'Wind Speed': 6.42,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 68.94,
#   'Humidity': 74,
#   'Cloudiness': 41,
#   'Wind Speed': 3,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Ilo',
#   'Lat': -17.6394,
#   'Lng': -71.3375,
#   'Max Temp': 59.94,
#   'Humidity': 84,
#   'Cloudiness': 71,
#   'Wind Speed': 5.17,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 47.16,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vrangel',
#   'Lat': 42.7297,
#   'Lng': 133.0839,
#   'Max Temp': 64.44,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.53,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'The Pas',
#   'Lat': 53.8251,
#   'Lng': -101.2541,
#   'Max Temp': 69.82,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Beihai',
#   'Lat': 21.4833,
#   'Lng': 109.1,
#   'Max Temp': 83.39,
#   'Humidity': 78,
#   'Cloudiness': 44,
#   'Wind Speed': 12.19,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Osa',
#   'Lat': 57.2829,
#   'Lng': 55.4567,
#   'Max Temp': 54.43,
#   'Humidity': 90,
#   'Cloudiness': 5,
#   'Wind Speed': 1.63,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Diapaga',
#   'Lat': 12.0708,
#   'Lng': 1.7889,
#   'Max Temp': 77.18,
#   'Humidity': 77,
#   'Cloudiness': 70,
#   'Wind Speed': 4.97,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 63.99,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 22.55,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chkalovsk',
#   'Lat': 56.7647,
#   'Lng': 43.2433,
#   'Max Temp': 59.86,
#   'Humidity': 87,
#   'Cloudiness': 60,
#   'Wind Speed': 10.92,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Massakory',
#   'Lat': 12.996,
#   'Lng': 15.7293,
#   'Max Temp': 85.66,
#   'Humidity': 62,
#   'Cloudiness': 71,
#   'Wind Speed': 3.27,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port-Cartier',
#   'Lat': 50.0334,
#   'Lng': -66.8654,
#   'Max Temp': 68.76,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 8.32,
#   'Country': 'GA',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Bar Harbor',
#   'Lat': 44.3876,
#   'Lng': -68.2039,
#   'Max Temp': 75.94,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Borazjan',
#   'Lat': 29.2666,
#   'Lng': 51.2159,
#   'Max Temp': 93.72,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 0.92,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'San Juan',
#   'Lat': -31.5375,
#   'Lng': -68.5364,
#   'Max Temp': 58.55,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 6.11,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 81.61,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 19.39,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 88.34,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 60.39,
#   'Humidity': 94,
#   'Cloudiness': 89,
#   'Wind Speed': 8.01,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 64.2,
#   'Humidity': 81,
#   'Cloudiness': 32,
#   'Wind Speed': 12.55,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Maun',
#   'Lat': -19.9833,
#   'Lng': 23.4167,
#   'Max Temp': 62.56,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Chara',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp': 63.09,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 79.97,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 10.4,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 80.71,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 77.4,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.35,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ponta Pora',
#   'Lat': -22.5361,
#   'Lng': -55.7256,
#   'Max Temp': 71.53,
#   'Humidity': 39,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Reconquista',
#   'Lat': -29.15,
#   'Lng': -59.65,
#   'Max Temp': 69.62,
#   'Humidity': 65,
#   'Cloudiness': 97,
#   'Wind Speed': 4.23,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Jose',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 95.9,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Omboue',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 71.91,
#   'Humidity': 90,
#   'Cloudiness': 84,
#   'Wind Speed': 7.02,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vangaindrano',
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp': 63.12,
#   'Humidity': 89,
#   'Cloudiness': 14,
#   'Wind Speed': 3.89,
#   'Country': 'GA',
#   'Weather Description': 'light rain'},
#  {'City': 'Acarau',
#   'Lat': -2.8856,
#   'Lng': -40.12,
#   'Max Temp': 79.32,
#   'Humidity': 78,
#   'Cloudiness': 52,
#   'Wind Speed': 14.2,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 60.89,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 91,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ternate',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 79.77,
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 4.32,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Suez',
#   'Lat': 29.9737,
#   'Lng': 32.5263,
#   'Max Temp': 76.05,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 8.77,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ayolas',
#   'Lat': -27.4,
#   'Lng': -56.9,
#   'Max Temp': 70.16,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 5.7,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Copiapo',
#   'Lat': -27.3667,
#   'Lng': -70.3333,
#   'Max Temp': 51.49,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 5.91,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Nyrob',
#   'Lat': 60.733,
#   'Lng': 56.7202,
#   'Max Temp': 56.01,
#   'Humidity': 85,
#   'Cloudiness': 85,
#   'Wind Speed': 1.3,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pamplona',
#   'Lat': 42.8169,
#   'Lng': -1.6432,
#   'Max Temp': 75.11,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'GA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Nkayi',
#   'Lat': -4.1841,
#   'Lng': 13.2884,
#   'Max Temp': 75.4,
#   'Humidity': 68,
#   'Cloudiness': 38,
#   'Wind Speed': 5.35,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Gonbad-E Qabus',
#   'Lat': 37.25,
#   'Lng': 55.1672,
#   'Max Temp': 81,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Pyinmana',
#   'Lat': 19.7333,
#   'Lng': 96.2167,
#   'Max Temp': 75.42,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 84.22,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Houston',
#   'Lat': 29.7633,
#   'Lng': -95.3633,
#   'Max Temp': 103.41,
#   'Humidity': 48,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'GA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 54.01,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Country': 'GA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vicksburg',
#   'Lat': 32.3526,
#   'Lng': -90.8779,
#   'Max Temp': 93.43,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Chardara',
#   'Lat': 41.2547,
#   'Lng': 67.9692,
#   'Max Temp': 82.2,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 10.31,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kropotkin',
#   'Lat': 45.4375,
#   'Lng': 40.5756,
#   'Max Temp': 59.09,
#   'Humidity': 65,
#   'Cloudiness': 2,
#   'Wind Speed': 6.89,
#   'Country': 'GA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 75.16,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'GA',
#   'Weather Description': 'scattered clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data2_df = pd.DataFrame(city_data2)
city_data2_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Souillac -20.5167   57.5167     69.58        66          72       13.65
# 1      Hobart -42.8794  147.3294     41.25        91          20        1.14
# 2      Namibe -15.1961   12.1522     62.67        89          23        1.68
# 3  San Matias -16.3667  -58.4000     83.97        26          35        4.38
# 4    Moorhead  46.8739  -96.7676     85.98        40           0       10.36
# 5        Uige  -7.6087   15.0613     66.49        71          61        2.75
# 6     Pericos  25.0500 -107.7000    103.91        43          15       13.35
# 7       Kapaa  22.0752 -159.3190     84.52        69          40       16.11
# 8    Saldanha -33.0117   17.9442     54.21        79          98       11.43
# 9    Cidreira -30.1811  -50.2056     62.53        91          92        2.10
#
#   Country Weather Description
# 0      GA       broken clouds
# 1      GA          few clouds
# 2      GA          few clouds
# 3      GA    scattered clouds
# 4      GA           clear sky
# 5      GA       broken clouds
# 6      GA          few clouds
# 7      GA    scattered clouds
# 8      GA     overcast clouds
# 9      GA     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data2_df = city_data2_df[new_column_order]
city_data2_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Souillac      GA -20.5167   57.5167     69.58        66          72
# 1      Hobart      GA -42.8794  147.3294     41.25        91          20
# 2      Namibe      GA -15.1961   12.1522     62.67        89          23
# 3  San Matias      GA -16.3667  -58.4000     83.97        26          35
# 4    Moorhead      GA  46.8739  -96.7676     85.98        40           0
# 5        Uige      GA  -7.6087   15.0613     66.49        71          61
# 6     Pericos      GA  25.0500 -107.7000    103.91        43          15
# 7       Kapaa      GA  22.0752 -159.3190     84.52        69          40
# 8    Saldanha      GA -33.0117   17.9442     54.21        79          98
# 9    Cidreira      GA -30.1811  -50.2056     62.53        91          92
#
#    Wind Speed Weather Description
# 0       13.65       broken clouds
# 1        1.14          few clouds
# 2        1.68          few clouds
# 3        4.38    scattered clouds
# 4       10.36           clear sky
# 5        2.75       broken clouds
# 6       13.35          few clouds
# 7       16.11    scattered clouds
# 8       11.43     overcast clouds
# 9        2.10     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data2_df.to_csv(output_data_file, index_label="City_ID")
